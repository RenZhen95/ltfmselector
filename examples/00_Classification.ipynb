# %% [markdown]
# ## Example of using LTFMSelector for Classification
# As an example, we will use LTFMSelector to deal with the UCI ML Breast Cancer Wisconsin dataset

# %%
from ltfmselector import LTFMSelector

import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
# Load breast cancer dataset
cancer_dataset = load_breast_cancer()

# Get data
X = cancer_dataset['data']

# Get target
y = cancer_dataset['target']
# - 0: malignant tumor
# - 1: benign tumor

# Get feature names
feature_names = cancer_dataset['feature_names']

# Get description
dataset_description = cancer_dataset['DESCR']

# %%
# Convert data into pandas DataFrame
cancer_df = pd.DataFrame(
    np.c_[X, y], columns = np.append(feature_names, ['target'])
)

# %% [markdown]
# The data will then be split for training and testing.
#
# Note: It is important that the training datasets (`X`) are passed as `pandas.DataFrame` and the label (`y`) as `pandas.Series`. Other forms will be accomodated for in later versions.

# %%
# Split the dataset for training and test
X_df = cancer_df.drop(['target'], axis=1)
y_df = cancer_df['target']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=5)

y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# %%
# Carry out feature scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=feature_names)
X_test  = pd.DataFrame(sc.transform(X_test), columns=feature_names)

# %% [markdown]
# We will now train an agent using LTFMSelector to select features and a prediction models, tailored to each sample.
#
# When initializing LTFMSelector, one necessary hyperparameter is the number of episodes, over which an agent is trained. My personal recommendation is set roughly 2-3 times the number of training examples.
#  - So for example here, we have 455 training examples: Hence, ~1300 episodes
#
# Another hyperparameter that should be set is `ptype`, which should be set to `classification` for this example.
#
# If `pModels=None`, a default choice of:
#  - Support Vector Machine
#  - Random Forest
#  - Gaussian Naive-Bayes
# will be implemented, all using the scikit-learn library with default hyperparameters. Users can also pass a list of classifier objects, which must have `fit` and `predict` call functions.

# %%
# Training an agent using LTFMSelector to select features and an appropriate prediction model tailored to each sample
AgentSelector = LTFMSelector(30, pType='classification') # If you got time, go for 1300

# %% [markdown]
# Train the agent by passing the training examples and label.
#
# The hyperparameter `agent_neuralnetwork` receives as an input a PyTorch neural network which will be used to learn the agent's policy. If `None`, a feed-forward (multilayer-perceptron) of with two hidden layers, each with 1024 units will be used.
#
# `lr` refers to the learning rate of the `AdamW` optimizer, used to update the policy network.
#
# The `fit` function returns a `dict<dict>` object, storing meta-information during the training process.
#
# Note: Just for demo purposes, training an agent over 1300 episodes may take some time but if you are simply interested in getting a feel for the interface then just set the number of episodes to 30 or less for now.

# %%
# Now letting the agent train, this could take some time ...
doc = AgentSelector.fit(X_train, y_train, agent_neuralnetwork=None, lr=1e-5)
# Out:
# === Episode 1 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 88
# - Features selected          : 28.0
# - Accumulated reward         : -53.34
# - Prediction model           : 1
# - Prediction model #(change) : 6
#
#
# === Episode 2 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 3
# - Features selected          : 2.0
# - Accumulated reward         : -0.02
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Episode 3 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 21
# - Features selected          : 13.0
# - Accumulated reward         : -3.17
# - Prediction model           : 2
# - Prediction model #(change) : 4
#
#
# === Episode 4 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 9
# - Features selected          : 8.0
# - Accumulated reward         : -0.08
# - Prediction model           : 1
# - Prediction model #(change) : 0
#
#
# === Episode 5 === === ===
# Episode terminated:
# - Iterations                 : 1
# - Features selected          : 0.0
# - Accumulated reward         : -5.0
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Episode 6 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 85
# - Features selected          : 28.0
# - Accumulated reward         : -46.38
# - Prediction model           : 1
# - Prediction model #(change) : 10
#
#
# === Episode 7 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 8
# - Features selected          : 5.0
# - Accumulated reward         : -2.05
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Episode 8 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 13
# - Features selected          : 6.0
# - Accumulated reward         : -1.11
# - Prediction model           : 2
# - Prediction model #(change) : 5
#
#
# === Episode 9 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 46
# - Features selected          : 22.0
# - Accumulated reward         : -20.25
# - Prediction model           : 0
# - Prediction model #(change) : 3
#
#
# === Episode 10 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 30
# - Features selected          : 18.0
# - Accumulated reward         : -5.24
# - Prediction model           : 2
# - Prediction model #(change) : 6
#
#
# === Episode 11 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 33
# - Features selected          : 15.0
# - Accumulated reward         : -8.24
# - Prediction model           : 0
# - Prediction model #(change) : 9
#
#
# === Episode 12 === === ===
# Episode terminated:
# - Iterations                 : 1
# - Features selected          : 0.0
# - Accumulated reward         : -5.0
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Episode 13 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 65
# - Features selected          : 23.0
# - Accumulated reward         : -14.5
# - Prediction model           : 2
# - Prediction model #(change) : 27
#
#
# === Episode 14 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 22
# - Features selected          : 5.0
# - Accumulated reward         : -0.21
# - Prediction model           : 0
# - Prediction model #(change) : 16
#
#
# === Episode 15 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 68
# - Features selected          : 22.0
# - Accumulated reward         : -19.48
# - Prediction model           : 2
# - Prediction model #(change) : 26
#
#
# === Episode 16 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 36
# - Features selected          : 14.0
# - Accumulated reward         : -6.29
# - Prediction model           : 2
# - Prediction model #(change) : 15
#
#
# === Episode 17 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 2
# - Features selected          : 1.0
# - Accumulated reward         : -0.01
# - Prediction model           : 1
# - Prediction model #(change) : 0
#
#
# === Episode 18 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 26.0
# - Accumulated reward         : -19.72
# - Prediction model           : 1
# - Prediction model #(change) : 46
#
#
# === Episode 19 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 2
# - Features selected          : 1.0
# - Accumulated reward         : -0.01
# - Prediction model           : 1
# - Prediction model #(change) : 0
#
#
# === Episode 20 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 6
# - Features selected          : 2.0
# - Accumulated reward         : -0.05
# - Prediction model           : 2
# - Prediction model #(change) : 3
#
#
# === Episode 21 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 38
# - Features selected          : 8.0
# - Accumulated reward         : -5.32
# - Prediction model           : 2
# - Prediction model #(change) : 24
#
#
# === Episode 22 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 8
# - Features selected          : 2.0
# - Accumulated reward         : -1.07
# - Prediction model           : 2
# - Prediction model #(change) : 5
#
#
# === Episode 23 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 20.0
# - Accumulated reward         : -19.72
# - Prediction model           : 2
# - Prediction model #(change) : 52
#
#
# === Episode 24 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 23.0
# - Accumulated reward         : -20.71
# - Prediction model           : 2
# - Prediction model #(change) : 48
#
#
# === Episode 25 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 67
# - Features selected          : 19.0
# - Accumulated reward         : -9.57
# - Prediction model           : 1
# - Prediction model #(change) : 38
#
#
# === Episode 26 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 21
# - Features selected          : 8.0
# - Accumulated reward         : -2.18
# - Prediction model           : 0
# - Prediction model #(change) : 10
#
#
# === Episode 27 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 39
# - Features selected          : 12.0
# - Accumulated reward         : -5.33
# - Prediction model           : 0
# - Prediction model #(change) : 21
#
#
# === Episode 28 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 82
# - Features selected          : 20.0
# - Accumulated reward         : -9.72
# - Prediction model           : 0
# - Prediction model #(change) : 52
#
#
# === Episode 29 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 8
# - Features selected          : 4.0
# - Accumulated reward         : -0.07
# - Prediction model           : 2
# - Prediction model #(change) : 3
#
#
# === Episode 30 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 50
# - Features selected          : 16.0
# - Accumulated reward         : -6.43
# - Prediction model           : 2
# - Prediction model #(change) : 27

# %%
# To test the trained agent on the test dataset
y_pred, doc_test = AgentSelector.predict(X_test)
# Out:
# === Test sample 0 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 66
# - Features selected          : 15.0
# - Accumulated reward         : -21.44
# - Prediction model           : 0
# - Prediction model #(change) : 29
#
#
# === Test sample 1 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 12
# - Features selected          : 6.0
# - Accumulated reward         : -0.11
# - Prediction model           : 2
# - Prediction model #(change) : 5
#
#
# === Test sample 2 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 42
# - Features selected          : 14.0
# - Accumulated reward         : -4.37
# - Prediction model           : 0
# - Prediction model #(change) : 23
#
#
# === Test sample 3 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 25
# - Features selected          : 9.0
# - Accumulated reward         : -1.23
# - Prediction model           : 0
# - Prediction model #(change) : 14
#
#
# === Test sample 4 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 41
# - Features selected          : 11.0
# - Accumulated reward         : -3.37
# - Prediction model           : 0
# - Prediction model #(change) : 26
#
#
# === Test sample 5 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 86
# - Features selected          : 18.0
# - Accumulated reward         : -30.55
# - Prediction model           : 2
# - Prediction model #(change) : 37
#
#
# === Test sample 6 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 54
# - Features selected          : 16.0
# - Accumulated reward         : -1.52
# - Prediction model           : 0
# - Prediction model #(change) : 36
#
#
# === Test sample 7 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 4
# - Features selected          : 3.0
# - Accumulated reward         : -0.03
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 8 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 85
# - Features selected          : 10.0
# - Accumulated reward         : -6.78
# - Prediction model           : 2
# - Prediction model #(change) : 68
#
#
# === Test sample 9 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -6.85
# - Prediction model           : 0
# - Prediction model #(change) : 68
#
#
# === Test sample 10 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 69
# - Features selected          : 13.0
# - Accumulated reward         : -4.64
# - Prediction model           : 2
# - Prediction model #(change) : 51
#
#
# === Test sample 11 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 63
# - Features selected          : 14.0
# - Accumulated reward         : -2.6
# - Prediction model           : 0
# - Prediction model #(change) : 46
#
#
# === Test sample 12 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 76
# - Features selected          : 14.0
# - Accumulated reward         : -57.18
# - Prediction model           : 1
# - Prediction model #(change) : 4
#
#
# === Test sample 13 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -19.72
# - Prediction model           : 1
# - Prediction model #(change) : 62
#
#
# === Test sample 14 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 15
# - Features selected          : 2.0
# - Accumulated reward         : -0.14
# - Prediction model           : 2
# - Prediction model #(change) : 12
#
#
# === Test sample 15 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 46
# - Features selected          : 8.0
# - Accumulated reward         : -3.42
# - Prediction model           : 0
# - Prediction model #(change) : 34
#
#
# === Test sample 16 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 45
# - Features selected          : 4.0
# - Accumulated reward         : -40.04
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 17 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -5.86
# - Prediction model           : 2
# - Prediction model #(change) : 75
#
#
# === Test sample 18 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 78
#
#
# === Test sample 19 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 84
#
#
# === Test sample 20 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 13
# - Features selected          : 4.0
# - Accumulated reward         : -0.12
# - Prediction model           : 2
# - Prediction model #(change) : 8
#
#
# === Test sample 21 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -3.88
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 22 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 23 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -7.84
# - Prediction model           : 0
# - Prediction model #(change) : 75
#
#
# === Test sample 24 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 9
# - Features selected          : 3.0
# - Accumulated reward         : -4.04
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Test sample 25 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 26 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -4.87
# - Prediction model           : 0
# - Prediction model #(change) : 76
#
#
# === Test sample 27 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -43.48
# - Prediction model           : 2
# - Prediction model #(change) : 34
#
#
# === Test sample 28 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 58
# - Features selected          : 6.0
# - Accumulated reward         : -0.57
# - Prediction model           : 2
# - Prediction model #(change) : 51
#
#
# === Test sample 29 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -12.79
# - Prediction model           : 2
# - Prediction model #(change) : 66
#
#
# === Test sample 30 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 30
# - Features selected          : 9.0
# - Accumulated reward         : -19.1
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Test sample 31 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 28
# - Features selected          : 3.0
# - Accumulated reward         : -23.04
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Test sample 32 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 41
# - Features selected          : 6.0
# - Accumulated reward         : -1.39
# - Prediction model           : 2
# - Prediction model #(change) : 33
#
#
# === Test sample 33 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 82
#
#
# === Test sample 34 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 35 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 36 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 37 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 38 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 39 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 46
# - Features selected          : 9.0
# - Accumulated reward         : -1.44
# - Prediction model           : 1
# - Prediction model #(change) : 35
#
#
# === Test sample 40 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 81
#
#
# === Test sample 41 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 78
# - Features selected          : 8.0
# - Accumulated reward         : -0.77
# - Prediction model           : 2
# - Prediction model #(change) : 69
#
#
# === Test sample 42 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 83
#
#
# === Test sample 43 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -3.88
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 44 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 2
# - Features selected          : 1.0
# - Accumulated reward         : -0.01
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 45 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 46 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -75.16
# - Prediction model           : 2
# - Prediction model #(change) : 6
#
#
# === Test sample 47 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 48 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 3.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 87
#
#
# === Test sample 49 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -70.21
# - Prediction model           : 0
# - Prediction model #(change) : 14
#
#
# === Test sample 50 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 51 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 25
# - Features selected          : 3.0
# - Accumulated reward         : -0.24
# - Prediction model           : 2
# - Prediction model #(change) : 21
#
#
# === Test sample 52 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 62
# - Features selected          : 5.0
# - Accumulated reward         : -1.6
# - Prediction model           : 0
# - Prediction model #(change) : 55
#
#
# === Test sample 53 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 54 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 55 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 87
#
#
# === Test sample 56 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 79
# - Features selected          : 6.0
# - Accumulated reward         : -1.77
# - Prediction model           : 2
# - Prediction model #(change) : 71
#
#
# === Test sample 57 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 58 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 87
#
#
# === Test sample 59 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 87
#
#
# === Test sample 60 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 2.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 88
#
#
# === Test sample 61 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 83
#
#
# === Test sample 62 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 47
# - Features selected          : 3.0
# - Accumulated reward         : -0.46
# - Prediction model           : 2
# - Prediction model #(change) : 43
#
#
# === Test sample 63 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 64 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 45
# - Features selected          : 4.0
# - Accumulated reward         : -0.44
# - Prediction model           : 2
# - Prediction model #(change) : 40
#
#
# === Test sample 65 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 66 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 81
#
#
# === Test sample 67 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 68 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 69 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 52
# - Features selected          : 8.0
# - Accumulated reward         : -0.51
# - Prediction model           : 2
# - Prediction model #(change) : 43
#
#
# === Test sample 70 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 86
#
#
# === Test sample 71 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -3.88
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 72 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 56
# - Features selected          : 4.0
# - Accumulated reward         : -0.55
# - Prediction model           : 2
# - Prediction model #(change) : 51
#
#
# === Test sample 73 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 82
#
#
# === Test sample 74 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 87
#
#
# === Test sample 75 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 76 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 34
# - Features selected          : 4.0
# - Accumulated reward         : -0.33
# - Prediction model           : 2
# - Prediction model #(change) : 29
#
#
# === Test sample 77 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -3.88
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 78 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -34.57
# - Prediction model           : 2
# - Prediction model #(change) : 47
#
#
# === Test sample 79 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 80 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -82.09
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Test sample 81 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 91
# - Features selected          : 6.0
# - Accumulated reward         : -1.89
# - Prediction model           : 0
# - Prediction model #(change) : 83
#
#
# === Test sample 82 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 83 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 86
#
#
# === Test sample 84 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 85 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 86 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 69
# - Features selected          : 9.0
# - Accumulated reward         : -2.66
# - Prediction model           : 0
# - Prediction model #(change) : 57
#
#
# === Test sample 87 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -21.7
# - Prediction model           : 2
# - Prediction model #(change) : 60
#
#
# === Test sample 88 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -44.47
# - Prediction model           : 2
# - Prediction model #(change) : 36
#
#
# === Test sample 89 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 87
#
#
# === Test sample 90 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 91 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 92 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 93 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 82
#
#
# === Test sample 94 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -37.54
# - Prediction model           : 1
# - Prediction model #(change) : 46
#
#
# === Test sample 95 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -8.83
# - Prediction model           : 2
# - Prediction model #(change) : 74
#
#
# === Test sample 96 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 87
#
#
# === Test sample 97 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 84
#
#
# === Test sample 98 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 99 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -64.27
# - Prediction model           : 2
# - Prediction model #(change) : 18
#
#
# === Test sample 100 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 3.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 88
#
#
# === Test sample 101 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 3.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 88
#
#
# === Test sample 102 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 85
#
#
# === Test sample 103 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 104 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 105 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 82
# - Features selected          : 7.0
# - Accumulated reward         : -1.8
# - Prediction model           : 0
# - Prediction model #(change) : 73
#
#
# === Test sample 106 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 85
#
#
# === Test sample 107 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -15.76
# - Prediction model           : 2
# - Prediction model #(change) : 69
#
#
# === Test sample 108 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 109 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 110 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 111 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86
#
#
# === Test sample 112 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 113 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 86

# %%
# Let's check out the classification accuracy
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc}")
# Out:
# Accuracy: 0.956140350877193

# %% [markdown]
# Now assuming you're satisfied with the performance, the next things to investigate might be the following:
# 1. Which features, and prediction model were selected to make a prediction about test sample 42?
# 2. Which features were most important for class 0 and 1?
# 3. Which prediction models seem to best suit this problem?

# %%
# 1. Which features, and prediction model were selected to make a prediction about test sample 42?
sample42_doc = doc_test[42]
print("For test sample 42:")
print(f" - True class: {y_test[42]} | Prediction: {y_pred[42]}")
print(f" - Prediction model selected: {AgentSelector.pModels[sample42_doc['PredModel']]}")
print(" - Features selected: ")
for i, feature_sel in enumerate(sample42_doc['Mask']):
    if feature_sel == 1.:
        print(f"   {i}: {feature_names[i]}")
# Out:
# For test sample 42:
#  - True class: 1.0 | Prediction: 1.0
#  - Prediction model selected: SVC()
#  - Features selected:
#    0: mean radius
#    14: smoothness error
#    16: concavity error
#    23: worst area
#    24: worst smoothness
#    26: worst concavity
#    29: worst fractal dimension

# %%
# 2. Which features were most important for class 0 and 1?

# Gather up indices according to predicitons
idxs_class0 = np.where(y_pred==0); idxs_class1 = np.where(y_pred==1)

# To gauge feature importance: One can simply count the number of time a feature was recruited when making a prediction
mask_class0 = np.zeros(len(feature_names))
mask_class1 = np.zeros(len(feature_names))

# Summing up feature occurence for predictions of class 0
for i in idxs_class0[0]:
    mask_class0 += doc_test[i]['Mask']

# Summing up feature occurence for predictions of class 1
for i in idxs_class1[0]:
    mask_class1 += doc_test[i]['Mask']

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
feature_count_df_0 = pd.DataFrame(
    {
        'Feature': feature_names, 'Count': mask_class0,
        'Class': ['Class 0' for _ in feature_names]
    }
)
feature_count_df_1 = pd.DataFrame(
    {
        'Feature': feature_names, 'Count': mask_class1,
        'Class': ['Class 1' for _ in feature_names]
    }
)
# Normalize the feature counts by the total number of times features were recruited
feature_count_df_0['Count'] = feature_count_df_0['Count'] / feature_count_df_0['Count'].sum()
feature_count_df_1['Count'] = feature_count_df_1['Count'] / feature_count_df_1['Count'].sum()

# Concatenating the two dataframes
feature_count_df = pd.concat([feature_count_df_0, feature_count_df_1])

# Plotting bar plots
sns.barplot(data=feature_count_df, x="Feature", y="Count", hue="Class")
plt.xlabel('Feature Names')
plt.xticks(rotation=90)
plt.ylabel('Normalized Count\n(by #features-queried)')
plt.tight_layout()
plt.show()

# %%
# 3. Which prediction models seem to best suit this problem?
pModelsName = [str(p).split('(')[0] for p in AgentSelector.pModels]

df_pModels_class0 = pd.DataFrame(
    {
        'pModel': pModelsName, 'Count': [0, 0, 0],
        'Class': ['Class 0', 'Class 0', 'Class 0']
    }
)
df_pModels_class0 = df_pModels_class0.set_index('pModel')
df_pModels_class1 = pd.DataFrame(
    {
        'pModel': pModelsName, 'Count': [0, 0, 0],
        'Class': ['Class 1', 'Class 1', 'Class 1']
    }
)
df_pModels_class1 = df_pModels_class1.set_index('pModel')

for i in doc_test:
    if y_pred[i] == 0.0:
        df_pModels_class0.at[pModelsName[doc_test[i]['PredModel']], 'Count'] += 1
    elif y_pred[i] == 1.0:
        df_pModels_class1.at[pModelsName[doc_test[i]['PredModel']], 'Count'] += 1

# Normalizing the prediciton model counts by total number of predictions
df_pModels_class0['Count'] = df_pModels_class0['Count'] / df_pModels_class0['Count'].sum()
df_pModels_class1['Count'] = df_pModels_class1['Count'] / df_pModels_class1['Count'].sum()

# Concatenating the two dataframes
df_pModels = pd.concat([df_pModels_class0, df_pModels_class1])
df_pModels.reset_index(inplace=True)

# Plotting bar plots
sns.barplot(data=df_pModels, x="pModel", y="Count", hue="Class")
plt.xlabel('Prediction Model')
plt.ylabel('Normalized Count\n(by #predictions)')
plt.tight_layout()
plt.show()
